# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-98f09099f855> in <module>
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
# !ls
# Out:
# Untitled.ipynb                  bezrobocie_wyksz_plec_lata.csv
# bezrobocie_plec_miesiecznie.csv

# %%
df = pd.read_csv('bezrobocie_wyksz_plec_lata.csv', sep = ";" )

# %%
list(df['Poziomy wykształcenia'].unique())
# Out:
# ['ogółem',
#  'wyższe',
#  'policealne oraz średnie zawodowe',
#  'średnie ogólnokształcące',
#  'zasadnicze zawodowe/branżowe',
#  'gimnazjalne, podstawowe i niepełne podstawowe']

# %%
dict(df['Poziomy wykształcenia'])
# Out:
# {0: 'ogółem',
#  1: 'ogółem',
#  2: 'ogółem',
#  3: 'ogółem',
#  4: 'ogółem',
#  5: 'ogółem',
#  6: 'ogółem',
#  7: 'ogółem',
#  8: 'ogółem',
#  9: 'ogółem',
#  10: 'ogółem',
#  11: 'ogółem',
#  12: 'ogółem',
#  13: 'ogółem',
#  14: 'ogółem',
#  15: 'wyższe',
#  16: 'wyższe',
#  17: 'wyższe',
#  18: 'wyższe',
#  19: 'wyższe',
#  20: 'wyższe',
#  21: 'wyższe',
#  22: 'wyższe',
#  23: 'wyższe',
#  24: 'wyższe',
#  25: 'wyższe',
#  26: 'wyższe',
#  27: 'wyższe',
#  28: 'wyższe',
#  29: 'wyższe',
#  30: 'policealne oraz średnie zawodowe',
#  31: 'policealne oraz średnie zawodowe',
#  32: 'policealne oraz średnie zawodowe',
#  33: 'policealne oraz średnie zawodowe',
#  34: 'policealne oraz średnie zawodowe',
#  35: 'policealne oraz średnie zawodowe',
#  36: 'policealne oraz średnie zawodowe',
#  37: 'policealne oraz średnie zawodowe',
#  38: 'policealne oraz średnie zawodowe',
#  39: 'policealne oraz średnie zawodowe',
#  40: 'policealne oraz średnie zawodowe',
# ...
